# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/MyDrive/Final_Capstone/Model/')

# %%
# !pip install pyamg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.7 MB 5.0 MB/s
# ...

# %%
# !python test.py --dataroot ../Image/F_Y --name F_Y --model cycle_gan  --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./CycleGAN/checkpoints
#                 crop_size: 256
#                  dataroot: ../Image/F_Y                  	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_path: ./CycleGAN/checkpoints
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
#                n_layers_D: 3
# ...
